# %%
import yfinance as yf

# %%
import sys
from pathlib import Path

sys.path.append(str(Path.cwd().parent))

# %%
from configs.universe import STOCK_UNIVERSE
import yfinance as yf
import pandas as pd

# %%
data = yf.download(
    STOCK_UNIVERSE,
    start="2020-01-01",
    end="2026-01-01",
    auto_adjust=False,
    group_by="column",
    threads=False,
    progress=False
)
# Out:
# HTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"Quote not found for symbol: TATAMOTORS.NS"}}}
# $TATAMOTORS.NS: possibly delisted; no timezone found
#
# 1 Failed download:
# ['TATAMOTORS.NS']: possibly delisted; no timezone found

# %%
data.shape
# Out:
# (1487, 180)

# %%
data.columns
# Out:
# MultiIndex([('Adj Close', 'ADANIPORTS.NS'),
#             ('Adj Close', 'ASIANPAINT.NS'),
#             ('Adj Close',   'AXISBANK.NS'),
#             ('Adj Close', 'BAJFINANCE.NS'),
#             ('Adj Close', 'BHARTIARTL.NS'),
#             ('Adj Close',  'COALINDIA.NS'),
#             ('Adj Close',    'HCLTECH.NS'),
#             ('Adj Close',   'HDFCBANK.NS'),
#             ('Adj Close', 'HINDUNILVR.NS'),
#             ('Adj Close',  'ICICIBANK.NS'),
#             ...
#             (   'Volume',   'RELIANCE.NS'),
#             (   'Volume',       'SBIN.NS'),
#             (   'Volume',  'SUNPHARMA.NS'),
#             (   'Volume', 'TATAMOTORS.NS'),
#             (   'Volume',  'TATASTEEL.NS'),
#             (   'Volume',        'TCS.NS'),
#             (   'Volume',      'TECHM.NS'),
#             (   'Volume',      'TITAN.NS'),
#             (   'Volume', 'ULTRACEMCO.NS'),
#             (   'Volume',      'WIPRO.NS')],
#            names=['Price', 'Ticker'], length=180)
